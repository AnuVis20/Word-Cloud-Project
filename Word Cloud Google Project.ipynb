# %%
punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    
uninteresting_words = ["the", "a", "to", "if", "is", "it", "of", "and", "or", "an", "as", "i", "me", "my", \
    "we", "our", "ours", "you", "your", "yours", "he", "she", "him", "his", "her", "hers", "its", "they", "them", \
    "their", "what", "which", "who", "whom", "this", "that", "am", "are", "was", "were", "be", "been", "being", \
    "have", "has", "had", "do", "does", "did", "but", "at", "by", "with", "from", "here", "when", "where", "how", \
    "all", "any", "both", "each", "few", "more", "some", "such", "no", "nor", "too", "very", "can", "will", "just"]

# %%
fd1 = open("charlie.txt","r",encoding="Latin")
text1 = fd1.read()
fd1.close()

# %%
text1.strip()
lines = text1.split("\n")

# %%
d5 = {}
for line in lines:
    words = line.split(" ")
    for word in words:
        if word.isalpha():
            if (word.lower() not in uninteresting_words) and (word.lower() not in punctuations):
                if len(word) > 8:
            # Check if the word is already in dictionary
                    if word in d5:
                        # Increment count of word by 1
                        d5[word] = d5[word] + 1
                    else:
                        # Add the word to dictionary with count 1
                        d5[word] = 1

# %%
# d5 = {}
# for line in lines:
#     words = line.split(" ")
#     for word in words:
#         if word.isalpha() and len(word) > 7:
#         # Check if the word is already in dictionary
#             if word in d5:
#                 # Increment count of word by 1
#                 d5[word] = d5[word] + 1
#             else:
#                 # Add the word to dictionary with count 1
#                 d5[word] = 1

# %%
# d5

# %%
# one way 
import wordcloud
cloud = wordcloud.WordCloud()
cloud.generate_from_frequencies(d5)
cloud.to_file("Words Cloud Project.jpg")

# %%
import wordcloud
cloud1 = wordcloud.WordCloud(width=1000, height=800)
cloud1.generate_from_frequencies(d5)
cloud.to_file("Word Cloud51.jpg")

# %%
# other way
from os import path
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(width=1600, height=800, background_color="black").generate(text1)
# Open a plot of the generated image.

plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig('word cloud (extended).png', facecolor='k', bbox_inches='tight')
